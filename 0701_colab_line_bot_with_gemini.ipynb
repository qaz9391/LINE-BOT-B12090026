# %% [markdown]
# <a href="https://colab.research.google.com/github/qaz9391/LINE-BOT-B12090026/blob/main/0701_colab_line_bot_with_gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Flask pyngrok line-bot-sdk requests --quiet
# !pip install google-genai --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 10.1 MB/s eta 0:00:00

# %%
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
line_channel_access_token = userdata.get('LINE_CHANNEL_ACCESS_TOKEN')
line_channel_secret = userdata.get('LINE_CHANNEL_SECRET')
gemini_api_key = userdata.get('GEMINI_API_KEY')
port = 5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
import requests

ngrok.set_auth_token(ngrok_authtoken)
tunnel = ngrok.connect(5051, name="linebot_tunnel")
webhook_url = tunnel.public_url

print(f"Ngrok URL: {webhook_url}")

# 自動更新 LINE Webhook URL
def update_line_webhook(webhook_url):
    """使用 LINE Messaging API 更新 Webhook URL"""
    url = "https://api.line.me/v2/bot/channel/webhook/endpoint"
    headers = {
        "Authorization": f"Bearer {line_channel_access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "endpoint": webhook_url
    }

    response = requests.put(url, headers=headers, json=data)

    if response.status_code == 200:
        print(f"✅ LINE Webhook URL 已自動更新為：{webhook_url}")
        return True
    else:
        print(f"❌ 更新失敗：{response.status_code} - {response.text}")
        return False

# 執行更新
update_line_webhook(webhook_url)
# Out:
# Ngrok URL: https://blazer-broadly-harpist.ngrok-free.dev
# ✅ LINE Webhook URL 已自動更新為：https://blazer-broadly-harpist.ngrok-free.dev
# True

# %%
from google import genai

client = genai.Client(api_key=gemini_api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="什麼是AI AGENT？"
)
print(response.text)
# Out:
# AI AGENT（人工智慧代理）是一種**能夠感知環境、進行思考決策、並採取行動以實現特定目標的軟體實體或系統**。它就像一個擁有智能、自主執行任務的「智能機器人」或「智能程式」。
#
# 簡單來說，一個AI Agent的運作週期通常包含以下幾個關鍵部分：
#
# 1.  **感知 (Perception)：** 代理人從其環境中收集資訊。這可以是透過API接收數據、監聽使用者輸入、讀取文件、從資料庫查詢、或像人類一樣透過感測器（例如攝影機、麥克風）獲取資訊。
# 2.  **思考/決策 (Reasoning/Decision-making)：** 根據感知到的資訊，代理人會分析當前狀態，判斷需要執行哪些步驟才能接近或達成其目標。這通常涉及運用人工智慧模型（如大型語言模型LLMs）、規則引擎、邏輯推理、規劃演算法等。
# 3.  **行動 (Action)：** 代理人根據其決策，對環境採取行動。這可能是發送API請求、撰寫郵件、執行程式碼、操作硬體、在網站上填寫表單、或者向使用者提供建議等。
# 4.  **學習 (Learning - 可選但強大)：** 更進階的AI Agent能夠從其行動的結果中學習，並調整其未來的決策策略，以提高效率或表現。
#
# **AI Agent 的主要特點：**
#
# *   **自主性 (Autonomy)：** 一旦設定好目標，AI Agent能夠在很少或沒有人為干預的情況下，獨立執行任務。
# *   **目標導向 (Goal-Oriented)：** 它們的行為都是為了達成一個或多個預設的目標。
# *   **環境互動 (Environment Interaction)：** AI Agent不只接收資訊，還會透過其行動影響其所處的環境。
# *   **適應性 (Adaptability)：** 某些AI Agent可以適應環境變化或新的資訊，調整其行為模式。
# *   **工具使用 (Tool Use)：** 現代AI Agent，特別是基於大型語言模型的Agent，常常能夠調用外部工具（APIs、程式碼解釋器、網頁瀏覽器等）來擴展其能力。
# *   **記憶/上下文 (Memory/Context)：** 能夠記住過去的互動和狀態，以便在後續的決策中利用這些資訊。
#
# ...

# %%
def stateless_query(payload):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=payload
    )
    return response.text

# %%
result = stateless_query("簡介明新科技大學")
print(result)
# Out:
# **明新科技大學 (Ming Hsin University of Science and Technology, MHUST)** 是一所位於台灣新竹縣湖口鄉的私立科技大學，以其悠久的歷史、實務導向的教學和與產業的緊密連結而聞名。
#
# 以下是明新科技大學的簡要介紹：
#
# 1.  **歷史與發展**：
#     *   **創立時間**：1966年，前身為「明新工業專科學校」，是台灣第一批私立工業專科學校之一。
#     *   **改制歷程**：1997年改制為「明新技術學院」，並於2002年獲教育部核准升格為「明新科技大學」。其發展歷程反映了台灣高等技職教育的演變。
#
# 2.  **地理位置**：
#     *   **坐落於**：新竹縣湖口鄉，鄰近新竹科學園區及其他工業區。
#     *   **優勢**：此地理位置使其在產學合作、學生實習與就業方面享有極大優勢，能與周邊高科技產業及服務業緊密結合。
#
# 3.  **學院與學術特色**：
#     *   **學院設置**：設有多個學院，通常包括：
#         *   工程學院
#         *   管理學院
#         *   服務事業學院
#         *   人文社會學院
#     *   **專業領域**：提供學士、碩士學位課程，涵蓋電機、電子、機械、資管、企管、休閒事業、觀光、旅館管理、幼兒保育、設計等多元化領域。
#     *   **教學重點**：強調實務教學、動手實作能力培養，並積極推動證照制度，以提升學生的職場競爭力。
#
# 4.  **教育理念與特色**：
#     *   **實務導向**：明新科大高度重視學用合一，課程設計緊密結合產業需求，透過實驗、實習、專題製作等方式，培養學生的專業技能。
#     *   **產學合作**：學校與眾多企業簽訂產學合作計畫，為學生提供豐富的實習機會和就業管道，使理論與實務無縫接軌。
#     *   **國際交流**：積極推動國際合作與交流，與海外學校建立夥伴關係，提供學生交換學習、海外實習等機會，拓展國際視野。
#     *   **全人教育**：在專業技能培養的同時，也注重學生的人文素養、品德教育及公民責任感，以培養具備跨領域能力和社會關懷的現代人才。
#
# ...

# %%
from flask import Flask, request, abort

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    ReplyMessageRequest,
    TextMessage,
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent,
)

app = Flask(__name__)

configuration = Configuration(access_token=line_channel_access_token)
handler = WebhookHandler(line_channel_secret)


@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    print("BODY: ", body)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    text = event.message.text
    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)
        if text.startswith('AI '):#這裡就是為甚麼在程式中註解為何要"AI "開頭gemini才會回應#
            prompt = text[3:]
            reply_text = stateless_query(prompt)
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=reply_text)]
                )
            )

        else:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=event.message.text),
                        TextMessage(text=event.message.text)]
                )
            )

if __name__ == "__main__":
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
# ...
